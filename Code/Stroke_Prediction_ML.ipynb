# %%
import os
import numpy as np
import pandas as pd

# %%
current_directory = os.getcwd()

# %%
new_directory ='\\Users\\User\\Downloads\\Py-DS-ML-Bootcamp-master\\Refactored_Py_DS_ML_Bootcamp-master\\03-Python-for-Data-Analysis-Pandas'

# %%
os.chdir(new_directory)

# %%
df = pd.read_csv('stroke_dataset.csv')##### creating a dataframe

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming df is your DataFrame and 'gender' is the column you want to encode
label_encoder = LabelEncoder()
df['gender_encoded'] = label_encoder.fit_transform(df['gender'])

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke  gender_encoded
# 0       1               1
# 1       1               0
# 2       1               1
# ...

# %%
# Assuming df is your DataFrame and you want to drop the 'gender' column
df.drop(columns=['gender'], inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming df is your DataFrame and 'ever_married' is the column you want to encode
label_encoder = LabelEncoder()
df['ever_married_encoded'] = label_encoder.fit_transform(df['ever_married'])

# %%
# Assuming df is your DataFrame and you want to drop the 'gender' column
df.drop(columns=['ever_married'], inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming df is your DataFrame and 'work_type' is the column you want to encode
label_encoder = LabelEncoder()
df['work_type_encoded'] = label_encoder.fit_transform(df['work_type'])

# %%
# Assuming df is your DataFrame and you want to drop the 'gender' column
df.drop(columns=['work_type'], inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming df is your DataFrame and 'residence_type' is the column you want to encode
label_encoder = LabelEncoder()
df['Residence_type_encoded'] = label_encoder.fit_transform(df['Residence_type'])

# %%
# Assuming df is your DataFrame and you want to drop the 'gender' column
df.drop(columns=['Residence_type'], inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming df is your DataFrame and 'residence_type' is the column you want to encode
label_encoder = LabelEncoder()
df['smoking_status_encoded'] = label_encoder.fit_transform(df['smoking_status'])

# %%
from sklearn.impute import SimpleImputer

# Assuming df is your DataFrame and 'bmi' is the column you want to impute
imputer = SimpleImputer(strategy='mean')
df['bmi_imputed'] = imputer.fit_transform(df[['bmi']])

# %%
# Assuming df is your DataFrame and you want to drop the 'gender' column
df.drop(columns=['bmi'], inplace=True)

# %%
# Assuming df is your DataFrame and you want to drop the 'gender' column
df.drop(columns=['smoking_status'], inplace=True)

# %%
df.head()
# Out:
#       id   age  hypertension  heart_disease Residence_type  avg_glucose_level  \
# 0   9046  67.0             0              1          Urban             228.69
# 1  51676  61.0             0              0          Rural             202.21
# 2  31112  80.0             0              1          Rural             105.92
# 3  60182  49.0             0              0          Urban             171.23
# 4   1665  79.0             1              0          Rural             174.12
#
#    stroke  gender_encoded  ever_married_encoded  work_type_encoded  \
# 0       1               1                     1                  2
# 1       1               0                     1                  3
# 2       1               1                     1                  2
# 3       1               0                     1                  2
# 4       1               0                     1                  3
#
#    Residence_type_encoded  bmi_imputed
# 0                       1    36.600000
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# Assuming df is your DataFrame
# Selecting only the numerical columns
numerical_columns = ['avg_glucose_level']

# Scaling the numerical features using Min-Max scaling
scaler = MinMaxScaler()
df[numerical_columns] = scaler.fit_transform(df[numerical_columns])

# %%
df.head()
# Out:
#       id   age  hypertension  heart_disease  avg_glucose_level  stroke  \
# 0   9046  67.0             0              1           0.801265       1
# 1  51676  61.0             0              0           0.679023       1
# 2  31112  80.0             0              1           0.234512       1
# 3  60182  49.0             0              0           0.536008       1
# 4   1665  79.0             1              0           0.549349       1
#
#    gender_encoded  ever_married_encoded  work_type_encoded  \
# 0               1                     1                  2
# 1               0                     1                  3
# 2               1                     1                  2
# 3               0                     1                  2
# 4               0                     1                  3
#
#    Residence_type_encoded  smoking_status_encoded  bmi_imputed
# 0                       1                       1    36.600000
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# Assuming df is your DataFrame
# Selecting only the numerical columns
numerical_columns = ['bmi_imputed']

# Scaling the numerical features using Min-Max scaling
scaler = MinMaxScaler()
df[numerical_columns] = scaler.fit_transform(df[numerical_columns])

# %%
from sklearn.preprocessing import MinMaxScaler

# Assuming df is your DataFrame
# Selecting only the numerical columns
numerical_columns = ['age']

# Scaling the numerical features using Min-Max scaling
scaler = MinMaxScaler()
df[numerical_columns] = scaler.fit_transform(df[numerical_columns])

# %%
# Assuming df is your DataFrame and you want to drop the 'gender' column
df.drop(columns=['id'], inplace=True)

# %%
df.head()
# Out:
#         age  hypertension  heart_disease Residence_type  avg_glucose_level  \
# 0  0.816895             0              1          Urban           0.801265
# 1  0.743652             0              0          Rural           0.679023
# 2  0.975586             0              1          Rural           0.234512
# 3  0.597168             0              0          Urban           0.536008
# 4  0.963379             1              0          Rural           0.549349
#
#    stroke  gender_encoded  ever_married_encoded  work_type_encoded  \
# 0       1               1                     1                  2
# 1       1               0                     1                  3
# 2       1               1                     1                  2
# 3       1               0                     1                  2
# 4       1               0                     1                  3
#
#    Residence_type_encoded  bmi_imputed
# 0                       1     0.301260
# ...

# %%
stroke_cases = df[df['stroke'] == 1]
non_stroke_cases = df[df['stroke'] == 0]

# Undersample the majority class
non_stroke_sample = non_stroke_cases.sample(n=len(stroke_cases), random_state=50)

# Combine the minority class with the undersampled majority class
balanced_data = pd.concat([stroke_cases, non_stroke_sample])

# Shuffle the dataset
balanced_data = balanced_data.sample(frac=1, random_state=50).reset_index(drop=True)

# Verify the class distribution
print(balanced_data['stroke'].value_counts())
# Out:
# stroke
# 0    249
# 1    249
# Name: count, dtype: int64

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
X = balanced_data.drop('stroke', axis=1)
y = balanced_data['stroke']
# Define and train the SVM classifier
svm_classifier = SVC(kernel='linear', random_state=42)
svm_classifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=50)

# %%
svm_classifier.fit(X_train, y_train)
# Define and train the SVM classifier
svm_classifier = SVC(kernel='linear', random_state=42)
svm_classifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
y_pred = svm_classifier.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8333333333333334
# Confusion Matrix:
#  [[65 13]
#  [12 60]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.83      0.84        78
#            1       0.82      0.83      0.83        72
#
#     accuracy                           0.83       150
#    macro avg       0.83      0.83      0.83       150
# weighted avg       0.83      0.83      0.83       150

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# Plot Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Predicted 0', 'Predicted 1'], yticklabels=['Actual 0', 'Actual 1'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Classification Report as DataFrame
report = classification_report(y_test, y_pred, output_dict=True)
df_report = pd.DataFrame(report).transpose()

# Plot Precision, Recall, and F1-Score
plt.figure(figsize=(10, 6))
df_report[['precision', 'recall', 'f1-score']].iloc[:-3].plot(kind='bar')
plt.title('Classification Report')
plt.xlabel('Classes')
plt.ylabel('Scores')
plt.xticks(rotation=0)
plt.ylim(0, 1)
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Varying hyperparameters to plot accuracy
# For example, let's vary the kernel parameter
kernels = ['linear', 'poly', 'rbf', 'sigmoid']
accuracies = []

for kernel in kernels:
    # Creating the Support Vector Machine model with the specified kernel
    svm_model = SVC(kernel=kernel, random_state=42)
    
    # Training the Support Vector Machine model
    svm_model.fit(X_train, y_train)
    
    # Predicting on the test set
    y_pred = svm_model.predict(X_test)
    
    # Calculating accuracy
    accuracy = accuracy_score(y_test, y_pred)
    accuracies.append(accuracy)

# Plotting
plt.figure(figsize=(8, 6))
plt.bar(kernels, accuracies, color='skyblue')
plt.title('Accuracy of SVM with Different Kernels')
plt.xlabel('Kernel')
plt.ylabel('Accuracy')
plt.ylim(0, 1)
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
y_prob = model.predict_proba(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.8533333333333334

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

conf_matrix = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Predicted 0', 'Predicted 1'], yticklabels=['Actual 0', 'Actual 1'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import classification_report

report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86        78
#            1       0.85      0.85      0.85        72
#
#     accuracy                           0.85       150
#    macro avg       0.85      0.85      0.85       150
# weighted avg       0.85      0.85      0.85       150

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, roc_curve, precision_recall_curve

# Plotting confusion matrix
def plot_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False)
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted Labels")
    plt.ylabel("True Labels")
    plt.show()

# Plotting ROC curve
def plot_roc_curve(y_true, y_pred_prob):
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_prob)
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='blue', lw=2)
    plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.show()

# Plotting Precision-Recall curve
def plot_precision_recall_curve(y_true, y_pred_prob):
    precision, recall, _ = precision_recall_curve(y_true, y_pred_prob)
    plt.figure(figsize=(8, 6))
    plt.plot(recall, precision, color='blue', lw=2)
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall Curve')
    plt.show()

# Plotting results
def plot_results(y_true, y_pred, y_pred_prob):
    plot_confusion_matrix(y_true, y_pred)
    plot_roc_curve(y_true, y_pred_prob)
    plot_precision_recall_curve(y_true, y_pred_prob)

# Assuming y_pred_prob contains the predicted probabilities of class 1
# For logistic regression, you can obtain these probabilities using `predict_proba` method
y_pred_prob = logreg_model.predict_proba(X_test)[:, 1]

# Plotting results
plot_results(y_test, y_pred, y_pred_prob)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 44
#      40     plot_precision_recall_curve(y_true, y_pred_prob)
#      42 # Assuming y_pred_prob contains the predicted probabilities of class 1
#      43 # For logistic regression, you can obtain these probabilities using `predict_proba` method
# ---> 44 y_pred_prob = logreg_model.predict_proba(X_test)[:, 1]
#      46 # Plotting results
#      47 plot_results(y_test, y_pred, y_pred_prob)
#
# NameError: name 'logreg_model' is not defined

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, precision_recall_curve

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred_prob)

# Plotting
plt.figure(figsize=(12, 8))

# Accuracy
plt.subplot(2, 3, 1)
plt.bar(["Accuracy"], [accuracy], color='skyblue')
plt.title("Accuracy")
plt.ylim(0, 1)

# Precision
plt.subplot(2, 3, 2)
plt.bar(["Precision"], [precision], color='salmon')
plt.title("Precision")
plt.ylim(0, 1)

# Recall
plt.subplot(2, 3, 3)
plt.bar(["Recall"], [recall], color='lightgreen')
plt.title("Recall")
plt.ylim(0, 1)

# F1 Score
plt.subplot(2, 3, 4)
plt.bar(["F1 Score"], [f1], color='orange')
plt.title("F1 Score")
plt.ylim(0, 1)

# AUC
fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
plt.subplot(2, 3, 5)
plt.plot(fpr, tpr, color='blue', lw=2)
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')

# Precision-Recall Curve
precision, recall, _ = precision_recall_curve(y_test, y_pred_prob)
plt.subplot(2, 3, 6)
plt.plot(recall, precision, color='blue', lw=2)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')

plt.tight_layout()
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_curve, roc_auc_score, PrecisionRecallDisplay
import seaborn as sns
import matplotlib.pyplot as plt

# %%
y_pred = model.predict(X_test)

# %%
y_prob = model.predict_proba(X_test)

# %%
ccuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.8533333333333334

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Predicted 0', 'Predicted 1'], yticklabels=['Actual 0', 'Actual 1'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()

# %%
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.77      0.75        78
#            1       0.74      0.69      0.71        72
#
#     accuracy                           0.73       150
#    macro avg       0.73      0.73      0.73       150
# weighted avg       0.73      0.73      0.73       150

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, precision_recall_curve
 
# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred_prob)

# Plotting
plt.figure(figsize=(12, 8))

# Accuracy
plt.subplot(2, 3, 1)
plt.bar(["Accuracy"], [accuracy], color='skyblue')
plt.title("Accuracy")
plt.ylim(0, 1)

# Precision
plt.subplot(2, 3, 2)
plt.bar(["Precision"], [precision], color='salmon')
plt.title("Precision")
plt.ylim(0, 1)

# Recall
plt.subplot(2, 3, 3)
plt.bar(["Recall"], [recall], color='lightgreen')
plt.title("Recall")
plt.ylim(0, 1)

# F1 Score
plt.subplot(2, 3, 4)
plt.bar(["F1 Score"], [f1], color='orange')
plt.title("F1 Score")
plt.ylim(0, 1)

# AUC
fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
plt.subplot(2, 3, 5)
plt.plot(fpr, tpr, color='blue', lw=2)
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')

# Precision-Recall Curve
precision, recall, _ = precision_recall_curve(y_test, y_pred_prob)
plt.subplot(2, 3, 6)
plt.plot(recall, precision, color='blue', lw=2)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')

plt.tight_layout()
plt.show()

# %%
# !pip install xgboost
# Out:
# ...
#   Obtaining dependency information for xgboost from https://files.pythonhosted.org/packages/24/ec/ad387100fa3cc2b9b81af0829b5ecfe75ec5bb19dd7c19d4fea06fb81802/xgboost-2.0.3-py3-none-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB 330.3 kB/s eta 0:05:02
#    ---------------------------------------- 0.0/99.8 MB 495.5 kB/s eta 0:03:22
#    ---------------------------------------- 0.2/99.8 MB 1.6 MB/s eta 0:01:03
#    ---------------------------------------- 0.4/99.8 MB 2.1 MB/s eta 0:00:48
#    ---------------------------------------- 0.5/99.8 MB 2.3 MB/s eta 0:00:44
#    ---------------------------------------- 0.7/99.8 MB 2.6 MB/s eta 0:00:39
#    ---------------------------------------- 0.9/99.8 MB 2.9 MB/s eta 0:00:35
#    ---------------------------------------- 1.1/99.8 MB 3.0 MB/s eta 0:00:33
#     --------------------------------------- 1.3/99.8 MB 3.1 MB/s eta 0:00:33
# ...

# %%
import xgboost as xgb
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, precision_recall_curve, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have already prepared your data and split it into X_train, X_test, y_train, y_test

# Initialize XGBoost classifier
xgb_model = xgb.XGBClassifier()

# Train the classifier
xgb_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = xgb_model.predict(X_test)
y_pred_prob = xgb_model.predict_proba(X_test)[:, 1]

# Calculate evaluation metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred_prob)

# Print the evaluation metrics
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("AUC:", auc)

# Plot confusion matrix
def plot_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False)
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted Labels")
    plt.ylabel("True Labels")
    plt.show()

# Plot ROC curve
def plot_roc_curve(y_true, y_pred_prob):
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_prob)
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='blue', lw=2)
    plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.show()

# Plot precision-recall curve
def plot_precision_recall_curve(y_true, y_pred_prob):
    precision, recall, _ = precision_recall_curve(y_true, y_pred_prob)
    plt.figure(figsize=(8, 6))
    plt.plot(recall, precision, color='blue', lw=2)
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall Curve')
    plt.show()

# Plotting results
def plot_results(y_true, y_pred, y_pred_prob):
    plot_confusion_matrix(y_true, y_pred)
    plot_roc_curve(y_true, y_pred_prob)
    plot_precision_recall_curve(y_true, y_pred_prob)

# Plot results
plot_results(y_test, y_pred, y_pred_prob)
# Out:
# Accuracy: 0.7133333333333334
# Precision: 0.6986301369863014
# Recall: 0.7083333333333334
# F1 Score: 0.703448275862069
# AUC: 0.8258547008547008

# %%
from sklearn.metrics import roc_auc_score

# Assuming you have true labels (y_test) and predicted probabilities of the positive class (y_pred_prob)

# Compute AUC
auc = roc_auc_score(y_test, y_pred_prob)

print("AUC:", auc)
# Out:
# AUC: 0.8258547008547008

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)

# Compute AUC
auc = roc_auc_score(y_test, y_pred_prob)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'AUC = {auc:.2f}')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Evaluation metrics
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'AUC']
values = [accuracy, precision, recall, f1, auc]

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(metrics, values, color=['skyblue', 'salmon', 'lightgreen', 'orange', 'blue'])
plt.title('Evaluation Metrics for XGBoost Classifier')
plt.xlabel('Metrics')
plt.ylabel('Values')
plt.ylim(0, 1)
plt.xticks(rotation=45)
plt.show()

# %%
from sklearn.metrics import roc_auc_score

# Assuming you have true labels (y_test) and predicted probabilities of the positive class (y_pred_prob) from your XGBoost classifier

# Compute AUC
auc = roc_auc_score(y_test, y_pred_prob)

print("AUC:", auc)
# Out:
# AUC: 0.8258547008547008

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
import matplotlib.pyplot as plt

# Assuming you have already prepared your data and split it into X_train, X_test, y_train, y_test

# Initialize Random Forest classifier
rf_classifier = RandomForestClassifier(random_state=42)

# Train the classifier
rf_classifier.fit(X_train, y_train)

# Make predictions on the test set
y_pred = rf_classifier.predict(X_test)
y_pred_prob = rf_classifier.predict_proba(X_test)[:, 1]

# Calculate evaluation metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred_prob)

# Print the evaluation metrics
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("AUC:", auc)

# Plot feature importances
plt.figure(figsize=(10, 6))
feat_importances = pd.Series(rf_classifier.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.title('Feature Importances')
plt.xlabel('Importance')
plt.ylabel('Features')
plt.show()
# Out:
# Accuracy: 0.78
# Precision: 0.76
# Recall: 0.7916666666666666
# F1 Score: 0.7755102040816326
# AUC: 0.854522792022792

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have already calculated the evaluation metrics (accuracy, precision, recall, f1, auc)

# Metrics names
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'AUC']

# Metrics values
values = [accuracy, precision, recall, f1, auc]

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(metrics, values, color=['skyblue', 'salmon', 'lightgreen', 'orange', 'blue'])
plt.title('Evaluation Metrics for Random Forest Classifier')
plt.xlabel('Metrics')
plt.ylabel('Values')
plt.ylim(0, 1)
plt.xticks(rotation=45)
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Calculate confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='g', cbar=False)
plt.title('Confusion Matrix for Random Forest Classifier')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# Initialize classifiers
logreg_model = LogisticRegression(random_state=42)
svm_model = SVC(kernel='linear', random_state=42, probability=True)
rf_model = RandomForestClassifier(random_state=42)
xgb_model = XGBClassifier(random_state=42)
dt_model = DecisionTreeClassifier(random_state=42)

# List of classifiers
classifiers = {'Logistic Regression': logreg_model,
               'Support Vector Machine': svm_model,
               'Random Forest': rf_model,
               'XGBoost': xgb_model,
               'Decision Tree': dt_model}

# Dictionary to store evaluation metrics
metrics_dict = {'Accuracy': accuracy_score,
                'Precision': precision_score,
                'Recall': recall_score,
                'F1 Score': f1_score,
                'AUC': roc_auc_score}

# Evaluate each classifier
results = {}
for name, clf in classifiers.items():
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    y_pred_prob = clf.predict_proba(X_test)[:, 1]
    metrics = {}
    for metric_name, metric_func in metrics_dict.items():
        metric_value = metric_func(y_test, y_pred) if metric_name != 'AUC' else metric_func(y_test, y_pred_prob)
        metrics[metric_name] = metric_value
    results[name] = metrics

# Print results
for name, metrics in results.items():
    print(f"Metrics for {name}:")
    for metric_name, metric_value in metrics.items():
        print(f"{metric_name}: {metric_value:.4f}")
    print()

# Plot results
import matplotlib.pyplot as plt

# Metrics to compare
metrics_to_compare = list(metrics_dict.keys())

# Plot
plt.figure(figsize=(12, 8))
for metric_name in metrics_to_compare:
    values = [results[name][metric_name] for name in classifiers.keys()]
    plt.bar(list(classifiers.keys()), values, label=metric_name)
plt.title('Comparison of Metrics for Different Classifiers')
plt.xlabel('Classifier')
plt.ylabel('Score')
plt.legend()
plt.xticks(rotation=45)
plt.show()
# Out:
# Metrics for Logistic Regression:
# Accuracy: 0.8533
# Precision: 0.8472
# Recall: 0.8472
# F1 Score: 0.8472
# AUC: 0.9001
#
# Metrics for Support Vector Machine:
# Accuracy: 0.8333
# Precision: 0.8219
# Recall: 0.8333
# F1 Score: 0.8276
# AUC: 0.8944
#
# Metrics for Random Forest:
# Accuracy: 0.7800
# Precision: 0.7600
# Recall: 0.7917
# F1 Score: 0.7755
# AUC: 0.8545
#
# Metrics for XGBoost:
# Accuracy: 0.7133
# Precision: 0.6986
# Recall: 0.7083
# F1 Score: 0.7034
# AUC: 0.8259
#
# Metrics for Decision Tree:
# Accuracy: 0.7333
# Precision: 0.7286
# Recall: 0.7083
# F1 Score: 0.7183
# AUC: 0.7324

# %%
import matplotlib.pyplot as plt
import numpy as np

# Metrics to compare
metrics_to_compare = list(metrics_dict.keys())

# Define colors for each model
colors = ['skyblue', 'salmon', 'lightgreen', 'orange', 'purple']

# Plot
plt.figure(figsize=(12, 8))
for i, metric_name in enumerate(metrics_to_compare):
    values = [results[name][metric_name] for name in classifiers.keys()]
    plt.bar(np.arange(len(classifiers)) + 0.15*i, values, width=0.15, label=metric_name, color=colors[i])
plt.title('Comparison of Metrics for Different Classifiers')
plt.xlabel('Classifier')
plt.ylabel('Score')
plt.legend()
plt.xticks(np.arange(len(classifiers)) + 0.3, list(classifiers.keys()), rotation=45)
plt.show()
